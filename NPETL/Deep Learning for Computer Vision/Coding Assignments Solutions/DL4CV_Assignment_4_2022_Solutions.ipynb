# %% [markdown]
# #### **Welcome to Assignment 4 on Deep Learning for Computer Vision.**
# This assignment is based on the content you learned in Week-4.
#
# #### **Instructions**
# 1. Use Python 3.x to run this notebook
# 2. Write your code only in between the lines 'YOUR CODE STARTS HERE' and 'YOUR CODE ENDS HERE'. You should not change anything else in the code cells, if you do, the answers you are supposed to get at the end of this assignment might be wrong.
# 3. Read documentation of each function carefully.
# 4. All the Best!

# %%
# Please DO NOT modify this cell.

import os
import os.path as osp
import random

import numpy as np
import torch

def set_seed(seed: int):

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    os.environ["PYTHONHASHSEED"] = str(seed)

# %% [markdown]
# ### We will be training a 1-hidden layer multi-layer perceptron on a randomly generated dataset.

# %%
# Please DO NOT modify this cell.

num_features = 10
classes = [0, 1, 2, 3, 4]
num_classes = len(classes)

num_samples = 100
num_train = 70
num_test = num_samples - num_train

# %%
# Please DO NOT modify this cell.
# We are creating a random feature set and a random label set.
# The features and labels have no semantic meaning and might as well be garbage.

set_seed(2022)

features = np.random.random_sample((num_samples, num_features))
labels = np.random.choice(classes, size = num_samples)

# Train-test split
x_train = features[:num_train]
x_test = features[num_train:num_samples]

x_train = torch.Tensor(x_train)
x_test = torch.Tensor(x_test)

y_train = labels[:num_train]
y_test = labels[num_train:num_samples]

y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

# %%
# Please DO NOT modify this cell.

print(f"Train features: {x_train.shape}")
print(f"Test features: {x_test.shape}")

print(f"Train labels: {y_train.shape}")
print(f"Train labels: {y_test.shape}")
# Out:
# Train features: torch.Size([70, 10])
# Test features: torch.Size([30, 10])
# Train labels: torch.Size([70])
# Train labels: torch.Size([30])

# %%
# Create train and test TensorDatasets from the respective numpy arrays

#### YOUR CODE STARTS HERE ####

train_dataset = torch.utils.data.TensorDataset(x_train, y_train)
test_dataset = torch.utils.data.TensorDataset(x_test, y_test)

#### YOUR CODE ENDS HERE ####

# %%
# Create dataloaders using the datasets created in the previous cell.
# Use a batch size of 64

#### YOUR CODE STARTS HERE ####

batch_size = 64

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size)

#### YOUR CODE ENDS HERE ####

# %% [markdown]
# ### Network Definition

# %%
# Please DO NOT modify this cell.

# Number of neurons in the hidden layer of our MLP
num_hidden = 512

# %%
import torch.nn as nn

class MLP(nn.Module):
    def __init__(self, num_features, num_classes, num_hidden):
        super(MLP, self).__init__()
        
        #### YOUR CODE STARTS HERE ####
        
        # define a linear layer with output channels as 32
        self.hidden = nn.Linear(num_features, num_hidden)
        # Define a ReLU activation
        self.relu = nn.ReLU()
        # define a linear layer with output features corresponding to the number of classes
        self.classifier = nn.Linear(num_hidden, num_classes)
        
        #### YOUR CODE ENDS HERE ####

    def forward(self, x):
        # Use the layers defined above in a sequential way (folow the same as the layer definitions above) and 
        # write the forward pass, use a relu activation after the hidden layer
        
        #### YOUR CODE STARTS HERE ####
        
        out = self.hidden(x)
        out = self.relu(out)
        out = self.classifier(out)
        
        #### YOUR CODE ENDS HERE ####
        
        return out

# %% [markdown]
# ### Training and Inference

# %%
def train(model, device, train_loader, optimizer, criterion, epoch):
    model.train()
    epoch_loss = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        
        #### YOUR CODE STARTS HERE ####
        
        # send the data, target to the device
        data = data.to(device)
        target = target.to(device)
    
        # flush out the gradients stored in optimizer
        optimizer.zero_grad()
        
        # pass the batch to the model and assign the output to variable named y_pred
        output = model(data)
        
        # calculate the loss (use CrossEntropyLoss in pytorch)
        loss = criterion(output, target)
        
        # do a backward pass
        loss.backward()
        
        # update the weights
        optimizer.step()
          
        #### YOUR CODE ENDS HERE ####
    
        # Store loss
        epoch_loss += loss.item() * data.shape[0]
        
    print(f"Train Average Loss: {epoch_loss/len(train_loader.dataset):.2f}")

# %%
def test(model, device, test_loader, criterion, mode):
    model.eval()
    test_loss = 0
    correct = 0
    
    with torch.no_grad():
        for data, target in test_loader:
            #### YOUR CODE STARTS HERE ####
            
            # send data, target to the device
            data = data.to(device)
            target = target.to(device)
            
            # pass the image to the model and assign the output to variable named output
            output = model(data)
            #### YOUR CODE ENDS HERE ####
            
            test_loss += criterion(output, target).item() * data.shape[0]  # sum up batch loss
            pred = output.argmax(dim = 1, keepdim = True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    test_acc = 100. * correct / len(test_loader.dataset)
    
    print(f"{mode} Average loss: {test_loss:.2f}")
    print(f"{mode} Accuracy: {correct}/{len(test_loader.dataset)} ({test_acc:.2f}%)")

# %%
set_seed(2022)

num_epochs = 300

#### YOUR CODE STARTS HERE ####

# check availability of GPU and set the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize MLP model
model = MLP(num_features, num_classes, num_hidden).to(device)

# Define Adam Optimizer with a learning rate of 0.001
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)

# Define CrossEntropyLoss as the criterion
criterion = nn.CrossEntropyLoss()

#### YOUR CODE ENDS HERE ####

for epoch in range(1, num_epochs+1):
    print(f"\nEpoch: {epoch}/{num_epochs}")
    
    train(model, device, train_loader, optimizer, criterion, epoch)
    test(model, device, test_loader, criterion, mode = "Test")
# Out:
# Epoch: 1/300
# Train Average Loss: 1.64
# Test Average loss: 1.58
# Test Accuracy: 12/30 (40.00%)
#
# Epoch: 2/300
# Train Average Loss: 1.61
# Test Average loss: 1.59
# Test Accuracy: 10/30 (33.33%)
#
# Epoch: 3/300
# Train Average Loss: 1.60
# Test Average loss: 1.60
# Test Accuracy: 10/30 (33.33%)
#
# Epoch: 4/300
# Train Average Loss: 1.59
# Test Average loss: 1.61
# Test Accuracy: 10/30 (33.33%)
#
# Epoch: 5/300
# Train Average Loss: 1.59
# Test Average loss: 1.61
# Test Accuracy: 10/30 (33.33%)
#
# Epoch: 6/300
# Train Average Loss: 1.58
# Test Average loss: 1.61
# Test Accuracy: 10/30 (33.33%)
#
# Epoch: 7/300
# Train Average Loss: 1.58
# Test Average loss: 1.61
# Test Accuracy: 10/30 (33.33%)
#
# Epoch: 8/300
# Train Average Loss: 1.57
# Test Average loss: 1.61
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 9/300
# Train Average Loss: 1.56
# Test Average loss: 1.62
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 10/300
# Train Average Loss: 1.56
# Test Average loss: 1.62
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 11/300
# Train Average Loss: 1.55
# Test Average loss: 1.62
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 12/300
# Train Average Loss: 1.54
# Test Average loss: 1.62
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 13/300
# Train Average Loss: 1.54
# Test Average loss: 1.62
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 14/300
# Train Average Loss: 1.53
# Test Average loss: 1.63
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 15/300
# Train Average Loss: 1.52
# Test Average loss: 1.64
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 16/300
# Train Average Loss: 1.51
# Test Average loss: 1.64
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 17/300
# Train Average Loss: 1.51
# Test Average loss: 1.65
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 18/300
# Train Average Loss: 1.50
# Test Average loss: 1.66
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 19/300
# Train Average Loss: 1.49
# Test Average loss: 1.67
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 20/300
# Train Average Loss: 1.49
# Test Average loss: 1.68
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 21/300
# Train Average Loss: 1.48
# Test Average loss: 1.69
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 22/300
# Train Average Loss: 1.48
# Test Average loss: 1.70
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 23/300
# Train Average Loss: 1.47
# Test Average loss: 1.71
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 24/300
# Train Average Loss: 1.46
# Test Average loss: 1.72
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 25/300
# Train Average Loss: 1.46
# Test Average loss: 1.73
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 26/300
# Train Average Loss: 1.45
# Test Average loss: 1.74
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 27/300
# Train Average Loss: 1.45
# Test Average loss: 1.74
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 28/300
# Train Average Loss: 1.44
# Test Average loss: 1.75
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 29/300
# Train Average Loss: 1.44
# Test Average loss: 1.77
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 30/300
# Train Average Loss: 1.43
# Test Average loss: 1.78
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 31/300
# Train Average Loss: 1.43
# Test Average loss: 1.79
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 32/300
# Train Average Loss: 1.42
# Test Average loss: 1.80
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 33/300
# Train Average Loss: 1.42
# Test Average loss: 1.81
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 34/300
# Train Average Loss: 1.42
# Test Average loss: 1.82
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 35/300
# Train Average Loss: 1.41
# Test Average loss: 1.83
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 36/300
# Train Average Loss: 1.41
# Test Average loss: 1.84
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 37/300
# Train Average Loss: 1.40
# Test Average loss: 1.85
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 38/300
# Train Average Loss: 1.40
# Test Average loss: 1.86
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 39/300
# Train Average Loss: 1.39
# Test Average loss: 1.87
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 40/300
# Train Average Loss: 1.39
# Test Average loss: 1.88
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 41/300
# Train Average Loss: 1.39
# Test Average loss: 1.89
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 42/300
# Train Average Loss: 1.38
# Test Average loss: 1.90
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 43/300
# Train Average Loss: 1.38
# Test Average loss: 1.91
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 44/300
# Train Average Loss: 1.37
# Test Average loss: 1.92
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 45/300
# Train Average Loss: 1.37
# Test Average loss: 1.93
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 46/300
# Train Average Loss: 1.36
# Test Average loss: 1.94
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 47/300
# Train Average Loss: 1.36
# Test Average loss: 1.95
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 48/300
# Train Average Loss: 1.35
# Test Average loss: 1.96
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 49/300
# Train Average Loss: 1.35
# Test Average loss: 1.97
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 50/300
# Train Average Loss: 1.34
# Test Average loss: 1.98
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 51/300
# Train Average Loss: 1.34
# Test Average loss: 1.99
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 52/300
# Train Average Loss: 1.33
# Test Average loss: 1.99
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 53/300
# Train Average Loss: 1.33
# Test Average loss: 2.00
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 54/300
# Train Average Loss: 1.32
# Test Average loss: 2.01
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 55/300
# Train Average Loss: 1.32
# Test Average loss: 2.02
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 56/300
# Train Average Loss: 1.31
# Test Average loss: 2.03
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 57/300
# Train Average Loss: 1.31
# Test Average loss: 2.03
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 58/300
# Train Average Loss: 1.30
# Test Average loss: 2.04
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 59/300
# Train Average Loss: 1.30
# Test Average loss: 2.05
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 60/300
# Train Average Loss: 1.29
# Test Average loss: 2.05
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 61/300
# Train Average Loss: 1.29
# Test Average loss: 2.06
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 62/300
# Train Average Loss: 1.28
# Test Average loss: 2.07
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 63/300
# Train Average Loss: 1.28
# Test Average loss: 2.07
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 64/300
# Train Average Loss: 1.27
# Test Average loss: 2.08
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 65/300
# Train Average Loss: 1.27
# Test Average loss: 2.08
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 66/300
# Train Average Loss: 1.26
# Test Average loss: 2.09
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 67/300
# Train Average Loss: 1.26
# Test Average loss: 2.09
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 68/300
# Train Average Loss: 1.25
# Test Average loss: 2.10
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 69/300
# Train Average Loss: 1.25
# Test Average loss: 2.11
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 70/300
# Train Average Loss: 1.24
# Test Average loss: 2.11
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 71/300
# Train Average Loss: 1.23
# Test Average loss: 2.12
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 72/300
# Train Average Loss: 1.23
# Test Average loss: 2.12
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 73/300
# Train Average Loss: 1.22
# Test Average loss: 2.13
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 74/300
# Train Average Loss: 1.22
# Test Average loss: 2.13
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 75/300
# Train Average Loss: 1.21
# Test Average loss: 2.14
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 76/300
# Train Average Loss: 1.21
# Test Average loss: 2.14
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 77/300
# Train Average Loss: 1.20
# Test Average loss: 2.15
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 78/300
# Train Average Loss: 1.19
# Test Average loss: 2.15
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 79/300
# Train Average Loss: 1.19
# Test Average loss: 2.16
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 80/300
# Train Average Loss: 1.18
# Test Average loss: 2.16
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 81/300
# Train Average Loss: 1.18
# Test Average loss: 2.16
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 82/300
# Train Average Loss: 1.17
# Test Average loss: 2.17
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 83/300
# Train Average Loss: 1.17
# Test Average loss: 2.17
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 84/300
# Train Average Loss: 1.16
# Test Average loss: 2.18
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 85/300
# Train Average Loss: 1.15
# Test Average loss: 2.18
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 86/300
# Train Average Loss: 1.15
# Test Average loss: 2.19
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 87/300
# Train Average Loss: 1.14
# Test Average loss: 2.19
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 88/300
# Train Average Loss: 1.14
# Test Average loss: 2.19
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 89/300
# Train Average Loss: 1.13
# Test Average loss: 2.20
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 90/300
# Train Average Loss: 1.12
# Test Average loss: 2.20
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 91/300
# Train Average Loss: 1.12
# Test Average loss: 2.20
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 92/300
# Train Average Loss: 1.11
# Test Average loss: 2.21
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 93/300
# Train Average Loss: 1.11
# Test Average loss: 2.21
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 94/300
# Train Average Loss: 1.10
# Test Average loss: 2.22
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 95/300
# Train Average Loss: 1.09
# Test Average loss: 2.22
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 96/300
# Train Average Loss: 1.09
# Test Average loss: 2.22
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 97/300
# Train Average Loss: 1.08
# Test Average loss: 2.22
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 98/300
# Train Average Loss: 1.08
# Test Average loss: 2.23
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 99/300
# Train Average Loss: 1.07
# Test Average loss: 2.23
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 100/300
# Train Average Loss: 1.07
# Test Average loss: 2.23
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 101/300
# Train Average Loss: 1.06
# Test Average loss: 2.24
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 102/300
# Train Average Loss: 1.05
# Test Average loss: 2.24
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 103/300
# Train Average Loss: 1.05
# Test Average loss: 2.24
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 104/300
# Train Average Loss: 1.04
# Test Average loss: 2.24
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 105/300
# Train Average Loss: 1.04
# Test Average loss: 2.25
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 106/300
# Train Average Loss: 1.03
# Test Average loss: 2.25
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 107/300
# Train Average Loss: 1.02
# Test Average loss: 2.25
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 108/300
# Train Average Loss: 1.02
# Test Average loss: 2.26
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 109/300
# Train Average Loss: 1.01
# Test Average loss: 2.26
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 110/300
# Train Average Loss: 1.01
# Test Average loss: 2.26
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 111/300
# Train Average Loss: 1.00
# Test Average loss: 2.26
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 112/300
# Train Average Loss: 1.00
# Test Average loss: 2.27
# Test Accuracy: 4/30 (13.33%)
#
# Epoch: 113/300
# Train Average Loss: 0.99
# Test Average loss: 2.27
# Test Accuracy: 3/30 (10.00%)
#
# Epoch: 114/300
# Train Average Loss: 0.98
# Test Average loss: 2.27
# Test Accuracy: 3/30 (10.00%)
#
# Epoch: 115/300
# Train Average Loss: 0.98
# Test Average loss: 2.27
# Test Accuracy: 3/30 (10.00%)
#
# Epoch: 116/300
# Train Average Loss: 0.97
# Test Average loss: 2.28
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 117/300
# Train Average Loss: 0.97
# Test Average loss: 2.28
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 118/300
# Train Average Loss: 0.96
# Test Average loss: 2.28
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 119/300
# Train Average Loss: 0.96
# Test Average loss: 2.28
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 120/300
# Train Average Loss: 0.95
# Test Average loss: 2.29
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 121/300
# Train Average Loss: 0.94
# Test Average loss: 2.29
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 122/300
# Train Average Loss: 0.94
# Test Average loss: 2.29
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 123/300
# Train Average Loss: 0.93
# Test Average loss: 2.29
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 124/300
# Train Average Loss: 0.93
# Test Average loss: 2.30
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 125/300
# Train Average Loss: 0.92
# Test Average loss: 2.30
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 126/300
# Train Average Loss: 0.92
# Test Average loss: 2.30
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 127/300
# Train Average Loss: 0.91
# Test Average loss: 2.30
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 128/300
# Train Average Loss: 0.91
# Test Average loss: 2.30
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 129/300
# Train Average Loss: 0.90
# Test Average loss: 2.31
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 130/300
# Train Average Loss: 0.89
# Test Average loss: 2.31
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 131/300
# Train Average Loss: 0.89
# Test Average loss: 2.31
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 132/300
# Train Average Loss: 0.88
# Test Average loss: 2.31
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 133/300
# Train Average Loss: 0.88
# Test Average loss: 2.31
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 134/300
# Train Average Loss: 0.87
# Test Average loss: 2.32
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 135/300
# Train Average Loss: 0.87
# Test Average loss: 2.32
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 136/300
# Train Average Loss: 0.86
# Test Average loss: 2.32
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 137/300
# Train Average Loss: 0.86
# Test Average loss: 2.33
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 138/300
# Train Average Loss: 0.85
# Test Average loss: 2.33
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 139/300
# Train Average Loss: 0.85
# Test Average loss: 2.33
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 140/300
# Train Average Loss: 0.84
# Test Average loss: 2.33
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 141/300
# Train Average Loss: 0.84
# Test Average loss: 2.33
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 142/300
# Train Average Loss: 0.83
# Test Average loss: 2.34
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 143/300
# Train Average Loss: 0.83
# Test Average loss: 2.34
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 144/300
# Train Average Loss: 0.82
# Test Average loss: 2.34
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 145/300
# Train Average Loss: 0.81
# Test Average loss: 2.35
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 146/300
# Train Average Loss: 0.81
# Test Average loss: 2.35
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 147/300
# Train Average Loss: 0.80
# Test Average loss: 2.35
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 148/300
# Train Average Loss: 0.80
# Test Average loss: 2.35
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 149/300
# Train Average Loss: 0.79
# Test Average loss: 2.36
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 150/300
# Train Average Loss: 0.79
# Test Average loss: 2.36
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 151/300
# Train Average Loss: 0.78
# Test Average loss: 2.36
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 152/300
# Train Average Loss: 0.78
# Test Average loss: 2.36
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 153/300
# Train Average Loss: 0.77
# Test Average loss: 2.37
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 154/300
# Train Average Loss: 0.77
# Test Average loss: 2.37
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 155/300
# Train Average Loss: 0.76
# Test Average loss: 2.37
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 156/300
# Train Average Loss: 0.76
# Test Average loss: 2.37
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 157/300
# Train Average Loss: 0.76
# Test Average loss: 2.38
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 158/300
# Train Average Loss: 0.75
# Test Average loss: 2.38
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 159/300
# Train Average Loss: 0.75
# Test Average loss: 2.38
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 160/300
# Train Average Loss: 0.74
# Test Average loss: 2.39
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 161/300
# Train Average Loss: 0.74
# Test Average loss: 2.39
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 162/300
# Train Average Loss: 0.73
# Test Average loss: 2.39
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 163/300
# Train Average Loss: 0.73
# Test Average loss: 2.39
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 164/300
# Train Average Loss: 0.72
# Test Average loss: 2.40
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 165/300
# Train Average Loss: 0.72
# Test Average loss: 2.40
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 166/300
# Train Average Loss: 0.71
# Test Average loss: 2.40
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 167/300
# Train Average Loss: 0.71
# Test Average loss: 2.40
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 168/300
# Train Average Loss: 0.70
# Test Average loss: 2.41
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 169/300
# Train Average Loss: 0.70
# Test Average loss: 2.41
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 170/300
# Train Average Loss: 0.69
# Test Average loss: 2.41
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 171/300
# Train Average Loss: 0.69
# Test Average loss: 2.42
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 172/300
# Train Average Loss: 0.68
# Test Average loss: 2.42
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 173/300
# Train Average Loss: 0.68
# Test Average loss: 2.42
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 174/300
# Train Average Loss: 0.68
# Test Average loss: 2.42
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 175/300
# Train Average Loss: 0.67
# Test Average loss: 2.43
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 176/300
# Train Average Loss: 0.67
# Test Average loss: 2.43
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 177/300
# Train Average Loss: 0.66
# Test Average loss: 2.43
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 178/300
# Train Average Loss: 0.66
# Test Average loss: 2.44
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 179/300
# Train Average Loss: 0.65
# Test Average loss: 2.44
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 180/300
# Train Average Loss: 0.65
# Test Average loss: 2.44
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 181/300
# Train Average Loss: 0.65
# Test Average loss: 2.45
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 182/300
# Train Average Loss: 0.64
# Test Average loss: 2.45
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 183/300
# Train Average Loss: 0.64
# Test Average loss: 2.45
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 184/300
# Train Average Loss: 0.63
# Test Average loss: 2.46
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 185/300
# Train Average Loss: 0.63
# Test Average loss: 2.46
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 186/300
# Train Average Loss: 0.62
# Test Average loss: 2.46
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 187/300
# Train Average Loss: 0.62
# Test Average loss: 2.47
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 188/300
# Train Average Loss: 0.62
# Test Average loss: 2.47
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 189/300
# Train Average Loss: 0.61
# Test Average loss: 2.47
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 190/300
# Train Average Loss: 0.61
# Test Average loss: 2.48
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 191/300
# Train Average Loss: 0.60
# Test Average loss: 2.48
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 192/300
# Train Average Loss: 0.60
# Test Average loss: 2.48
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 193/300
# Train Average Loss: 0.60
# Test Average loss: 2.48
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 194/300
# Train Average Loss: 0.59
# Test Average loss: 2.49
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 195/300
# Train Average Loss: 0.59
# Test Average loss: 2.49
# Test Accuracy: 5/30 (16.67%)
#
# Epoch: 196/300
# Train Average Loss: 0.58
# Test Average loss: 2.50
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 197/300
# Train Average Loss: 0.58
# Test Average loss: 2.50
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 198/300
# Train Average Loss: 0.58
# Test Average loss: 2.50
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 199/300
# Train Average Loss: 0.57
# Test Average loss: 2.51
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 200/300
# Train Average Loss: 0.57
# Test Average loss: 2.51
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 201/300
# Train Average Loss: 0.56
# Test Average loss: 2.51
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 202/300
# Train Average Loss: 0.56
# Test Average loss: 2.52
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 203/300
# Train Average Loss: 0.56
# Test Average loss: 2.52
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 204/300
# Train Average Loss: 0.55
# Test Average loss: 2.52
# Test Accuracy: 6/30 (20.00%)
#
# Epoch: 205/300
# Train Average Loss: 0.55
# Test Average loss: 2.53
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 206/300
# Train Average Loss: 0.54
# Test Average loss: 2.53
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 207/300
# Train Average Loss: 0.54
# Test Average loss: 2.53
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 208/300
# Train Average Loss: 0.54
# Test Average loss: 2.54
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 209/300
# Train Average Loss: 0.53
# Test Average loss: 2.54
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 210/300
# Train Average Loss: 0.53
# Test Average loss: 2.54
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 211/300
# Train Average Loss: 0.53
# Test Average loss: 2.55
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 212/300
# Train Average Loss: 0.52
# Test Average loss: 2.55
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 213/300
# Train Average Loss: 0.52
# Test Average loss: 2.55
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 214/300
# Train Average Loss: 0.52
# Test Average loss: 2.56
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 215/300
# Train Average Loss: 0.51
# Test Average loss: 2.56
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 216/300
# Train Average Loss: 0.51
# Test Average loss: 2.57
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 217/300
# Train Average Loss: 0.50
# Test Average loss: 2.57
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 218/300
# Train Average Loss: 0.50
# Test Average loss: 2.57
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 219/300
# Train Average Loss: 0.50
# Test Average loss: 2.58
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 220/300
# Train Average Loss: 0.49
# Test Average loss: 2.58
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 221/300
# Train Average Loss: 0.49
# Test Average loss: 2.58
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 222/300
# Train Average Loss: 0.49
# Test Average loss: 2.59
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 223/300
# Train Average Loss: 0.48
# Test Average loss: 2.59
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 224/300
# Train Average Loss: 0.48
# Test Average loss: 2.59
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 225/300
# Train Average Loss: 0.48
# Test Average loss: 2.60
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 226/300
# Train Average Loss: 0.47
# Test Average loss: 2.60
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 227/300
# Train Average Loss: 0.47
# Test Average loss: 2.61
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 228/300
# Train Average Loss: 0.47
# Test Average loss: 2.61
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 229/300
# Train Average Loss: 0.46
# Test Average loss: 2.61
# Test Accuracy: 7/30 (23.33%)
#
# Epoch: 230/300
# Train Average Loss: 0.46
# Test Average loss: 2.62
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 231/300
# Train Average Loss: 0.46
# Test Average loss: 2.62
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 232/300
# Train Average Loss: 0.45
# Test Average loss: 2.63
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 233/300
# Train Average Loss: 0.45
# Test Average loss: 2.63
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 234/300
# Train Average Loss: 0.45
# Test Average loss: 2.64
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 235/300
# Train Average Loss: 0.44
# Test Average loss: 2.64
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 236/300
# Train Average Loss: 0.44
# Test Average loss: 2.64
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 237/300
# Train Average Loss: 0.44
# Test Average loss: 2.65
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 238/300
# Train Average Loss: 0.43
# Test Average loss: 2.65
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 239/300
# Train Average Loss: 0.43
# Test Average loss: 2.66
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 240/300
# Train Average Loss: 0.43
# Test Average loss: 2.66
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 241/300
# Train Average Loss: 0.43
# Test Average loss: 2.66
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 242/300
# Train Average Loss: 0.42
# Test Average loss: 2.67
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 243/300
# Train Average Loss: 0.42
# Test Average loss: 2.67
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 244/300
# Train Average Loss: 0.42
# Test Average loss: 2.68
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 245/300
# Train Average Loss: 0.41
# Test Average loss: 2.68
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 246/300
# Train Average Loss: 0.41
# Test Average loss: 2.68
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 247/300
# Train Average Loss: 0.41
# Test Average loss: 2.69
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 248/300
# Train Average Loss: 0.40
# Test Average loss: 2.69
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 249/300
# Train Average Loss: 0.40
# Test Average loss: 2.70
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 250/300
# Train Average Loss: 0.40
# Test Average loss: 2.70
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 251/300
# Train Average Loss: 0.40
# Test Average loss: 2.70
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 252/300
# Train Average Loss: 0.39
# Test Average loss: 2.71
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 253/300
# Train Average Loss: 0.39
# Test Average loss: 2.71
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 254/300
# Train Average Loss: 0.39
# Test Average loss: 2.72
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 255/300
# Train Average Loss: 0.38
# Test Average loss: 2.72
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 256/300
# Train Average Loss: 0.38
# Test Average loss: 2.72
# Test Accuracy: 8/30 (26.67%)
#
# Epoch: 257/300
# Train Average Loss: 0.38
# Test Average loss: 2.73
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 258/300
# Train Average Loss: 0.38
# Test Average loss: 2.73
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 259/300
# Train Average Loss: 0.37
# Test Average loss: 2.74
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 260/300
# Train Average Loss: 0.37
# Test Average loss: 2.74
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 261/300
# Train Average Loss: 0.37
# Test Average loss: 2.75
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 262/300
# Train Average Loss: 0.36
# Test Average loss: 2.75
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 263/300
# Train Average Loss: 0.36
# Test Average loss: 2.75
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 264/300
# Train Average Loss: 0.36
# Test Average loss: 2.76
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 265/300
# Train Average Loss: 0.36
# Test Average loss: 2.76
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 266/300
# Train Average Loss: 0.35
# Test Average loss: 2.77
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 267/300
# Train Average Loss: 0.35
# Test Average loss: 2.77
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 268/300
# Train Average Loss: 0.35
# Test Average loss: 2.77
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 269/300
# Train Average Loss: 0.35
# Test Average loss: 2.78
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 270/300
# Train Average Loss: 0.34
# Test Average loss: 2.78
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 271/300
# Train Average Loss: 0.34
# Test Average loss: 2.79
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 272/300
# Train Average Loss: 0.34
# Test Average loss: 2.79
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 273/300
# Train Average Loss: 0.34
# Test Average loss: 2.79
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 274/300
# Train Average Loss: 0.33
# Test Average loss: 2.80
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 275/300
# Train Average Loss: 0.33
# Test Average loss: 2.80
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 276/300
# Train Average Loss: 0.33
# Test Average loss: 2.81
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 277/300
# Train Average Loss: 0.33
# Test Average loss: 2.81
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 278/300
# Train Average Loss: 0.32
# Test Average loss: 2.81
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 279/300
# Train Average Loss: 0.32
# Test Average loss: 2.82
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 280/300
# Train Average Loss: 0.32
# Test Average loss: 2.82
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 281/300
# Train Average Loss: 0.32
# Test Average loss: 2.83
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 282/300
# Train Average Loss: 0.32
# Test Average loss: 2.83
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 283/300
# Train Average Loss: 0.31
# Test Average loss: 2.83
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 284/300
# Train Average Loss: 0.31
# Test Average loss: 2.84
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 285/300
# Train Average Loss: 0.31
# Test Average loss: 2.84
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 286/300
# Train Average Loss: 0.31
# Test Average loss: 2.85
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 287/300
# Train Average Loss: 0.30
# Test Average loss: 2.85
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 288/300
# Train Average Loss: 0.30
# Test Average loss: 2.86
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 289/300
# Train Average Loss: 0.30
# Test Average loss: 2.86
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 290/300
# Train Average Loss: 0.30
# Test Average loss: 2.86
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 291/300
# Train Average Loss: 0.30
# Test Average loss: 2.87
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 292/300
# Train Average Loss: 0.29
# Test Average loss: 2.87
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 293/300
# Train Average Loss: 0.29
# Test Average loss: 2.88
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 294/300
# Train Average Loss: 0.29
# Test Average loss: 2.88
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 295/300
# Train Average Loss: 0.29
# Test Average loss: 2.88
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 296/300
# Train Average Loss: 0.28
# Test Average loss: 2.89
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 297/300
# Train Average Loss: 0.28
# Test Average loss: 2.89
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 298/300
# Train Average Loss: 0.28
# Test Average loss: 2.90
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 299/300
# Train Average Loss: 0.28
# Test Average loss: 2.90
# Test Accuracy: 9/30 (30.00%)
#
# Epoch: 300/300
# Train Average Loss: 0.28
# Test Average loss: 2.91
# Test Accuracy: 9/30 (30.00%)

# %% [markdown]
# ### Question 1
#
# What are total number of parameters in the model?
#
# 1. 8197
# 2. 18521
# 3. 8356
# 4. 9105

# %%
print(sum(p.numel() for p in model.parameters()))
# Out:
# 8197

# %% [markdown]
# ### Question 2
#
# Report the final train accuracy (If you are not getting the exact number shown in
# options, please report the closest number).
#
# 1. 58%
# 2. 93%
# 3. 100%
# 4. 89%

# %%
test(model, device, train_loader, criterion, mode = "Train")
# Out:
# Train Average loss: 0.27
# Train Accuracy: 70/70 (100.00%)

# %% [markdown]
# ### Question 3
#
# Report the final test accuracy (If you are not getting the exact number shown in
# options, please report the closest number).
#
# 1. 30%
# 2. 40%
# 3. 10%
# 4. 70%

# %%
test(model, device, test_loader, criterion, mode = "Test")
# Out:
# Test Average loss: 2.91
# Test Accuracy: 9/30 (30.00%)

# %% [markdown]
# ### [Optional]
#
# - Think about the experimented that we just conducted.
# - We trained a 1 hidden layer MLP with a completely random dataset (garbage, effectively) with no connection between the features and the labels. In spite of that, the MLP model was able to memorize the training set.
# - Consequently, the model was unable to discern any meaningful patterns in the test set.
# - While this may not be a practically useful, it goes to show the power of simple 1 hidden layer MLPs.
# - Read through the following paper for a better treatment of this phenomenon: __Understanding deep learning requires rethinking generalization__ https://arxiv.org/abs/1611.03530 (ICLR 2017)
