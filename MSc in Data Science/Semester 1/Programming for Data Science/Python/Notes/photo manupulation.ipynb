# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, transform
# %matplotlib inline

# %%
myimage = io.imread('bridge.jpg')
plt.imshow(myimage);
print(type(myimage)); print(myimage.shape); print(myimage.ndim)
#print(myimage[0,:,:])
# Out:
# <class 'numpy.ndarray'>
# (175, 287, 3)
# 3

# %%
plt.imshow(myimage[0:80,:,:])

# %%
modified_image1 = myimage[0:175:2,0:287:2,:]
plt.imshow(modified_image1)

# %%
modified_image2 = myimage.copy()
modified_image2[0:175:4,0:287:4,:]=30
plt.imshow(modified_image2)

# %%
part_image1 = myimage[:,:,0]
#print(part_image1)
plt.imshow(part_image1)

# %%
part_image2 = myimage[:,:,1]
plt.imshow(part_image2)

# %%
part_image3 = myimage[:,:,2]
plt.imshow(part_image3)

# %%
sum_of_parts = part_image1+part_image2+part_image3
plt.imshow(sum_of_parts)

# %%
l1 = []
for i in range(175):
    e = np.vstack((part_image1[i,:][np.newaxis,:],part_image2[i,:][np.newaxis,:],part_image3[i,:][np.newaxis:]))
    l1.append(e)

# %%
l2 = [x.T for x in l1]

# %%
final_img = np.vstack(l2).reshape(175,287,3)

# %%
plt.imshow(final_img)

# %%
# Get the value of the pixel at the 10th row and 20th column
[10, 20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13896/3658513390.py in <module>
#       1 # Get the value of the pixel at the 10th row and 20th column
# ----> 2 camera[10, 20]
#
# NameError: name 'camera' is not defined

# %%
nrows, ncols = myi.shape
row, col = np.ogrid[:nrows, :ncols]
cnt_row, cnt_col = nrows / 2, ncols / 2
outer_disk_mask = ((row - cnt_row)**2 + (col - cnt_col)**2 >
                    (nrows / 2)**2)
camera[outer_disk_mask] = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13896/2459895021.py in <module>
#       1 nrows, ncols = camera.shape
# ----> 2 row, col = np.ogrid[:nrows, :ncols]
#       3 cnt_row, cnt_col = nrows / 2, ncols / 2
#       4 outer_disk_mask = ((row - cnt_row)**2 + (col - cnt_col)**2 >
#       5                     (nrows / 2)**2)
#
# NameError: name 'np' is not defined
